# %%
from sur.models import *

# %%
m = Mixture()
m.add_many("methane co2 n-decane", "0.25 0.50 0.25")

# %%
m.set_interaction('rkpr', 'kij', 'methane', 'co2', .1)
m.set_interaction('rkpr', 'kij', 'co2', 'n-decane',  0.091)
m.set_interaction('rkpr', 'lij', 'co2', 'n-decane',  -0.90)

# %%
env = m.get_envelope('rkpr')

# %%
print env.get_txt()

# %%
# %matplotlib inline

# %%
env.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-66d23ff33cfe> in <module>()
# ----> 1 env.plot()
#
# /home/tin/lab/envelope-sur/sur/models.py in plot(self, fig)
#     725             if p_start:
#     726                 p = np.insert(self.p[start:index], 0, p_start)
# --> 727             if self.index_cri > 1:
#     728                 p_start = self.p_cri[i]
#     729                 p = np.append(p, p_start)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
